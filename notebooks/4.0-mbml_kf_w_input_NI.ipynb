# %% [markdown]
# # Kalman filters Niger
#
# Data from Niger is substantially scarcer, with just 57 points available.

# %% [markdown]
# ### Table of contents
# 1. [Data](#Data)
# 2. [Model with the vector c fixed as [0, 1]](#Model-with-the-vector-c-fixed-as-[0,-1])
# 3. [Model with the vector c as a random variable with prior](#Model-with-the-vector-c-as-a-random-variable-with-prior)
# 4. [Model without input (2 hidden variables)](#Model-without-input)

# %%
import sys
from os.path import pardir, join

import pandas as pd
import numpy as np
import numpyro
import numpyro.distributions as dist
from numpyro import handlers
from numpyro.infer import MCMC, NUTS
import matplotlib.pyplot as plt


import jax
import jax.numpy as jnp
from jax import random, vmap
from jax.scipy.special import logsumexp
from jax import lax
np.random.seed(42)

# %%
plt.style.use('ggplot')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 10)

# %%
from sklearn.preprocessing import StandardScaler

# %%
ROOT = pardir
DATA = join(ROOT, "data", "processed")

# %% [markdown]
# ## Data

# %% [markdown]
# The data from Niger has 57 data points (compare with the 1197 from Italy).

# %%
data = pd.read_csv(join(DATA, 'data_niger_sixcol.csv')).values
X = data[:, 2:].astype(np.float_)
y = data[:,1].astype(np.float_)

n_train = 40
n_test = len(y)-n_train

idx_train = [*range(0,n_train)]
idx_test = [*range(n_train, len(y))]

y_train = y[idx_train]
y_test = y[idx_test]

# %% [markdown]
# ## Model with the vector c fixed as [0, 1]

# %%
sys.path.append(join(ROOT, "src", "models"))
sys.path.append(join(ROOT, "src", "visualization"))

from kf_input import model_wo_c, model_w_c
from train import train_kf
from visualize import get_samples, plot_samples, plot_forecast

# %%
mcmc = train_kf(model_wo_c, y_train, n_train, n_test, x=X, num_samples=3000, num_warmup=1000)
# Out:
# sample: 100%|██████████| 4000/4000 [06:42<00:00,  9.93it/s, 1023 steps of size 2.99e-03. acc. prob=0.85]

# %%
hmc_samples = get_samples(mcmc)
plot_samples(hmc_samples, ["beta", "tau", "sigma"])

# %%
plot_forecast(hmc_samples, idx_train, idx_test, y_train, y_test)

# %% [markdown]
# ## Model with the vector c as a random variable with prior

# %%
mcmc2 = train_kf(model_w_c, y_train, n_train, n_test, x=X, num_samples=3000, num_warmup=1000)
# Out:
# sample: 100%|██████████| 4000/4000 [06:52<00:00,  9.70it/s, 9 steps of size 6.72e-04. acc. prob=0.75]

# %%
hmc_samples = get_samples(mcmc2)
plot_samples(hmc_samples, ["beta", "tau", "sigma"])

# %%
plot_forecast(hmc_samples, idx_train, idx_test, y_train, y_test)

# %% [markdown]
# ## Model without input

# %%
from kf import twoh_c_kf

# %%
mcmc3 = train_kf(twoh_c_kf, y_train, n_train, n_test, x=None, num_samples=3000, num_warmup=1000)
# Out:
# sample: 100%|██████████| 4000/4000 [06:08<00:00, 10.85it/s, 1023 steps of size 9.05e-04. acc. prob=0.95]

# %%
hmc_samples = get_samples(mcmc3)
plot_samples(hmc_samples, ["beta", "tau", "sigma"])

# %%
plot_forecast(hmc_samples, idx_train, idx_test, y_train, y_test)
